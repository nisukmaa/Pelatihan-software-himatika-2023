# %%
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/imdwipayana/Python-Project-2023/main/Project/asuransi_mobil.csv')

# %%
data.head()
# Out:
#    IDENTITAS                  UMUR JENIS_KELAMIN  PENGALAMAN_MENGEMUDI  \
# 0     569520   lebih dari 65 tahun     perempuan  kurang dari 10 tahun
# 1     750365  kurang dari 25 tahun     laki-laki  kurang dari 10 tahun
# 2     199901  kurang dari 25 tahun     perempuan  kurang dari 10 tahun
# 3     478866  kurang dari 25 tahun     laki-laki  kurang dari 10 tahun
# 4     731664    antara 25-40 tahun     laki-laki    antara 10-20 tahun
#
#     PENDIDIKAN        PENGHASILAN  SKOR_KREDIT PEMILIK_KENDARAAN  \
# 0          SMA  lebih dari 3x UMR     0.629027                ya
# 1    tidak ada    kurang dari UMR     0.357757             tidak
# 2          SMA    antara 1-2x UMR     0.493146                ya
# 3  universitas    antara 1-2x UMR     0.206013                ya
# 4    tidak ada    antara 1-2x UMR     0.388366                ya
#
#   TAHUN_PRODUKSI         STATUS       ANAK  KODE_POS  KM_PER_TAHUN  \
# 0   setelah 2020  belum menikah        ada     10238       12000.0
# ...

# %%
data.describe()
# Out:
#            IDENTITAS  SKOR_KREDIT      KODE_POS  KM_PER_TAHUN  TILANG_NGEBUT  \
# count   10000.000000  9018.000000  10000.000000   9043.000000   10000.000000
# mean   500521.906800     0.515813  19864.548400  11697.003207       1.482900
# std    290030.768758     0.137688  18915.613855   2818.434528       2.241966
# min       101.000000     0.053358  10238.000000   2000.000000       0.000000
# 25%    249638.500000     0.417191  10238.000000  10000.000000       0.000000
# 50%    501777.000000     0.525033  10238.000000  12000.000000       0.000000
# 75%    753974.500000     0.618312  32765.000000  14000.000000       2.000000
# max    999976.000000     0.960819  92101.000000  22000.000000      22.000000
#
#        TILANG_MABUK  KECELAKAAN_SEBELUMNYA
# count   10000.00000           10000.000000
# mean        0.23920               1.056300
# std         0.55499               1.652454
# min         0.00000               0.000000
# 25%         0.00000               0.000000
# ...

# %%
data.dtypes
# Out:
# IDENTITAS                  int64
# UMUR                      object
# JENIS_KELAMIN             object
# PENGALAMAN_MENGEMUDI      object
# PENDIDIKAN                object
# PENGHASILAN               object
# SKOR_KREDIT              float64
# PEMILIK_KENDARAAN         object
# TAHUN_PRODUKSI            object
# STATUS                    object
# ANAK                      object
# KODE_POS                   int64
# KM_PER_TAHUN             float64
# JENIS_KENDARAAN           object
# TILANG_NGEBUT              int64
# TILANG_MABUK               int64
# KECELAKAAN_SEBELUMNYA      int64
# KLAIM                     object
# dtype: object

# %%
data.isnull().sum()
# Out:
# IDENTITAS                  0
# UMUR                       0
# JENIS_KELAMIN              0
# PENGALAMAN_MENGEMUDI       0
# PENDIDIKAN                 0
# PENGHASILAN                0
# SKOR_KREDIT              982
# PEMILIK_KENDARAAN          0
# TAHUN_PRODUKSI             0
# STATUS                     0
# ANAK                       0
# KODE_POS                   0
# KM_PER_TAHUN             957
# JENIS_KENDARAAN            0
# TILANG_NGEBUT              0
# TILANG_MABUK               0
# KECELAKAAN_SEBELUMNYA      0
# KLAIM                      0
# dtype: int64

# %%
data_categorical =['KM_PER_TAHUN','SKOR_KREDIT']

# %%
data_drop = data.drop(data_categorical, axis =1)

# %%
data_drop.isnull().sum()
# Out:
# IDENTITAS                0
# UMUR                     0
# JENIS_KELAMIN            0
# PENGALAMAN_MENGEMUDI     0
# PENDIDIKAN               0
# PENGHASILAN              0
# PEMILIK_KENDARAAN        0
# TAHUN_PRODUKSI           0
# STATUS                   0
# ANAK                     0
# KODE_POS                 0
# JENIS_KENDARAAN          0
# TILANG_NGEBUT            0
# TILANG_MABUK             0
# KECELAKAAN_SEBELUMNYA    0
# KLAIM                    0
# dtype: int64

# %%
data_drop.dtypes
# Out:
# IDENTITAS                 int64
# UMUR                     object
# JENIS_KELAMIN            object
# PENGALAMAN_MENGEMUDI     object
# PENDIDIKAN               object
# PENGHASILAN              object
# PEMILIK_KENDARAAN        object
# TAHUN_PRODUKSI           object
# STATUS                   object
# ANAK                     object
# KODE_POS                  int64
# JENIS_KENDARAAN          object
# TILANG_NGEBUT             int64
# TILANG_MABUK              int64
# KECELAKAAN_SEBELUMNYA     int64
# KLAIM                    object
# dtype: object

# %%
data_drop.UMUR.unique()
# Out:
# array(['lebih dari 65 tahun', 'kurang dari 25 tahun',
#        'antara 25-40 tahun', 'antara 40-65 tahun'], dtype=object)

# %%
data_drop['UMUR']= \
data_drop['UMUR'].map({'lebih dari 65 tahun':4,'antara 40-65 tahun':3,'antara 25-40 tahun':2,'kurang dari 25 tahun':1})

# %%
data_drop.PENGHASILAN.unique()
# Out:
# array(['lebih dari 3x UMR', 'kurang dari UMR', 'antara 1-2x UMR',
#        'antara 2-3x UMR'], dtype=object)

# %%
data_drop['PENGHASILAN']= \
data_drop['PENGHASILAN'].map({'lebih dari 3x UMR':4,'antara 2-3x UMR':3,'antara 1-2x UMR':2,'kurang dari UMR':1})

# %%
 data.JENIS_KENDARAAN.unique()
# Out:
# array(['keluarga', 'sport'], dtype=object)

# %%
data_drop['JENIS_KENDARAAN']= \
data_drop['JENIS_KENDARAAN'].map({'keluarga':1,'sport':0})

# %%
data.TAHUN_PRODUKSI.unique()
# Out:
# array(['setelah 2020', 'sebelum 2020'], dtype=object)

# %%
data_drop['TAHUN_PRODUKSI']= \
data_drop['TAHUN_PRODUKSI'].map({'setelah 2020':1,'sebelum 2020':0})

# %%
data.PEMILIK_KENDARAAN.unique()
# Out:
# array(['ya', 'tidak'], dtype=object)

# %%
data_drop['PEMILIK_KENDARAAN']= \
data_drop['PEMILIK_KENDARAAN'].map({'ya':1,'tidak':0})

# %%
data.PENGALAMAN_MENGEMUDI.unique()
# Out:
# array(['kurang dari 10 tahun', 'antara 10-20 tahun', 'antara 20-30 tahun',
#        'lebih dari 30 tahun'], dtype=object)

# %%
data_drop['PENGALAMAN_MENGEMUDI']= \
data_drop['PENGALAMAN_MENGEMUDI'].map({'kurang dari 10 tahun':1,'antara 10-20 tahun':2,'antara 20-30 tahun':3, 'lebih dari 30 tahun':4})

# %%
data.KLAIM.unique()
# Out:
# array(['tidak', 'ya'], dtype=object)

# %%
data_drop['KLAIM']= \
data_drop['KLAIM'].map({'ya':1,'tidak':0})

# %%
data.JENIS_KELAMIN.unique()
# Out:
# array(['perempuan', 'laki-laki'], dtype=object)

# %%
data_drop['JENIS_KELAMIN']= \
data_drop['JENIS_KELAMIN'].map({'laki-laki':1,'perempuan':0})

# %%
data.PENDIDIKAN.unique()
# Out:
# array(['SMA', 'tidak ada', 'universitas'], dtype=object)

# %%
data_drop['PENDIDIKAN']= \
data_drop['PENDIDIKAN'].map({'universitas':3,'SMA':2,'tidak ada':1})

# %%
data.STATUS.unique()
# Out:
# array(['belum menikah', 'menikah'], dtype=object)

# %%
data_drop['STATUS']= \
data_drop['STATUS'].map({'menikah':1,'belum menikah':0})

# %%
data.ANAK.unique()
# Out:
# array(['ada', 'tidak ada'], dtype=object)

# %%
data_drop['ANAK']= \
data_drop['ANAK'].map({'ada':1,'tidak ada':0})

# %%
data_drop.columns
# Out:
# Index(['IDENTITAS', 'UMUR', 'JENIS_KELAMIN', 'PENGALAMAN_MENGEMUDI',
#        'PENDIDIKAN', 'PENGHASILAN', 'PEMILIK_KENDARAAN', 'TAHUN_PRODUKSI',
#        'STATUS', 'ANAK', 'KODE_POS', 'JENIS_KENDARAAN', 'TILANG_NGEBUT',
#        'TILANG_MABUK', 'KECELAKAAN_SEBELUMNYA', 'KLAIM'],
#       dtype='object')

# %%
data_drop.dtypes
# Out:
# IDENTITAS                  int64
# UMUR                       int64
# JENIS_KELAMIN              int64
# PENGALAMAN_MENGEMUDI       int64
# PENDIDIKAN                 int64
# PENGHASILAN                int64
# PEMILIK_KENDARAAN          int64
# TAHUN_PRODUKSI             int64
# STATUS                     int64
# ANAK                       int64
# KODE_POS                   int64
# JENIS_KENDARAAN            int64
# TILANG_NGEBUT              int64
# TILANG_MABUK               int64
# KECELAKAAN_SEBELUMNYA      int64
# KLAIM                    float64
# dtype: object

# %%
data_drop.head()
# Out:
#    IDENTITAS  UMUR  JENIS_KELAMIN  PENGALAMAN_MENGEMUDI  PENDIDIKAN  \
# 0     569520     4              0                     1           2
# 1     750365     1              1                     1           1
# 2     199901     1              0                     1           2
# 3     478866     1              1                     1           3
# 4     731664     2              1                     2           1
#
#    PENGHASILAN  PEMILIK_KENDARAAN  TAHUN_PRODUKSI  STATUS  ANAK  KODE_POS  \
# 0            4                  1               1       0     1     10238
# 1            1                  0               0       0     0     10238
# 2            2                  1               0       0     0     10238
# 3            2                  1               0       0     1     32765
# 4            2                  1               0       0     0     32765
#
#    JENIS_KENDARAAN  TILANG_NGEBUT  TILANG_MABUK  KECELAKAAN_SEBELUMNYA  KLAIM
# ...

# %%
data_drop.describe()
# Out:
#            IDENTITAS          UMUR  JENIS_KELAMIN  PENGALAMAN_MENGEMUDI  \
# count   10000.000000  10000.000000   10000.000000          10000.000000
# mean   500521.906800      2.489500       0.499000              2.069300
# std    290030.768758      1.025278       0.500024              0.990452
# min       101.000000      1.000000       0.000000              1.000000
# 25%    249638.500000      2.000000       0.000000              1.000000
# 50%    501777.000000      2.000000       0.000000              2.000000
# 75%    753974.500000      3.000000       1.000000              3.000000
# max    999976.000000      4.000000       1.000000              4.000000
#
#         PENDIDIKAN   PENGHASILAN  PEMILIK_KENDARAAN  TAHUN_PRODUKSI  \
# count  10000.00000  10000.000000       10000.000000    10000.000000
# mean       2.20130      2.899600           0.697000        0.303300
# std        0.73745      1.149109           0.459578        0.459707
# ...

# %% [markdown]
# # Menggunakan Normalisasi

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler()
d = scaler.fit_transform(data_drop)
data_normalisasi = pd.DataFrame(d, columns=data_drop.columns)
data_normalisasi.head(10)
# Out:
# C:\Users\Gedebayu\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:400: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\Gedebayu\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:401: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
#    IDENTITAS      UMUR  JENIS_KELAMIN  PENGALAMAN_MENGEMUDI  PENDIDIKAN  \
# 0   0.569490  1.000000            0.0              0.000000         0.5
# 1   0.750358  0.000000            1.0              0.000000         0.0
# 2   0.199825  0.000000            0.0              0.000000         0.5
# 3   0.478825  0.000000            1.0              0.000000         1.0
# 4   0.731654  0.333333            1.0              0.333333         0.0
# 5   0.877566  0.666667            0.0              0.666667         0.5
# 6   0.930149  1.000000            1.0              1.000000         0.5
# 7   0.460963  0.333333            0.0              0.000000         1.0
# ...

# %%
data_normalisasi.describe()
# Out:
#           IDENTITAS          UMUR  JENIS_KELAMIN  PENGALAMAN_MENGEMUDI  \
# count  10000.000000  10000.000000   10000.000000          10000.000000
# mean       0.500483      0.496500       0.499000              0.356433
# std        0.290067      0.341759       0.500024              0.330151
# min        0.000000      0.000000       0.000000              0.000000
# 25%        0.249569      0.333333       0.000000              0.000000
# 50%        0.501739      0.333333       0.000000              0.333333
# 75%        0.753968      0.666667       1.000000              0.666667
# max        1.000000      1.000000       1.000000              1.000000
#
#          PENDIDIKAN   PENGHASILAN  PEMILIK_KENDARAAN  TAHUN_PRODUKSI  \
# count  10000.000000  10000.000000       10000.000000    10000.000000
# mean       0.600650      0.633200           0.697000        0.303300
# std        0.368725      0.383036           0.459578        0.459707
# ...

# %%
data_fix = pd.concat([data_normalisasi, data_drop], axis=1, join='inner')
data_fix.head()
# Out:
#    IDENTITAS      UMUR  JENIS_KELAMIN  PENGALAMAN_MENGEMUDI  PENDIDIKAN  \
# 0   0.569490  1.000000            0.0              0.000000         0.5
# 1   0.750358  0.000000            1.0              0.000000         0.0
# 2   0.199825  0.000000            0.0              0.000000         0.5
# 3   0.478825  0.000000            1.0              0.000000         1.0
# 4   0.731654  0.333333            1.0              0.333333         0.0
#
#    PENGHASILAN  PEMILIK_KENDARAAN  TAHUN_PRODUKSI  STATUS  ANAK  ...  \
# 0     1.000000                1.0             1.0     0.0   1.0  ...
# 1     0.000000                0.0             0.0     0.0   0.0  ...
# 2     0.333333                1.0             0.0     0.0   0.0  ...
# 3     0.333333                1.0             0.0     0.0   1.0  ...
# 4     0.333333                1.0             0.0     0.0   0.0  ...
#
#    PEMILIK_KENDARAAN  TAHUN_PRODUKSI  STATUS  ANAK  KODE_POS  JENIS_KENDARAAN  \
# ...

# %%
X = data_fix.drop(['KLAIM'], axis =1) 
y = data_fix['KLAIM']
